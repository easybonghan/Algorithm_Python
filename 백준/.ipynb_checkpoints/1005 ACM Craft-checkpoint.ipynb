# %% [markdown]
# # [ACM Craft](https://www.acmicpc.net/problem/1005)
#
# ## 문제
# 서기 2012년! 드디어 2년간 수많은 국민들을 기다리게 한 게임 ACM Craft (Association of Construction Manager Craft)가 발매되었다.
#
# 이 게임은 지금까지 나온 게임들과는 다르게 ACM크래프트는 다이나믹한 게임 진행을 위해 건물을 짓는 순서가 정해져 있지 않다. 즉, 첫 번째 게임과 두 번째 게임이 건물을 짓는 순서가 다를 수도 있다. 매 게임시작 시 건물을 짓는 순서가 주어진다. 또한 모든 건물은 각각 건설을 시작하여 완성이 될 때까지 Delay가 존재한다.
#
# ![](https://www.acmicpc.net/upload/201003/star.JPG)
#
#
# 위의 예시를 보자.
#
# 이번 게임에서는 다음과 같이 건설 순서 규칙이 주어졌다. 1번 건물의 건설이 완료된다면 2번과 3번의 건설을 시작할수 있다. (동시에 진행이 가능하다) 그리고 4번 건물을 짓기 위해서는 2번과 3번 건물이 모두 건설 완료되어야지만 4번건물의 건설을 시작할수 있다.
#
# 따라서 4번건물의 건설을 완료하기 위해서는 우선 처음 1번 건물을 건설하는데 10초가 소요된다. 그리고 2번 건물과 3번 건물을 동시에 건설하기 시작하면 2번은 1초뒤에 건설이 완료되지만 아직 3번 건물이 완료되지 않았으므로 4번 건물을 건설할 수 없다. 3번 건물이 완성되고 나면 그때 4번 건물을 지을수 있으므로 4번 건물이 완성되기까지는 총 120초가 소요된다.
#
# 프로게이머 최백준은 애인과의 데이트 비용을 마련하기 위해 서강대학교배 ACM크래프트 대회에 참가했다! 최백준은 화려한 컨트롤 실력을 가지고 있기 때문에 모든 경기에서 특정 건물만 짓는다면 무조건 게임에서 이길 수 있다. 그러나 매 게임마다 특정건물을 짓기 위한 순서가 달라지므로 최백준은 좌절하고 있었다. 백준이를 위해 특정건물을 가장 빨리 지을 때까지 걸리는 최소시간을 알아내는 프로그램을 작성해주자.
#
#
#
# ## 입력
# 첫째 줄에는 테스트케이스의 개수 T가 주어진다. 각 테스트 케이스는 다음과 같이 주어진다. 첫째 줄에 건물의 개수 N 과 건물간의 건설순서규칙의 총 개수 K이 주어진다. (건물의 번호는 1번부터 N번까지 존재한다)
#
# 둘째 줄에는 각 건물당 건설에 걸리는 시간 D가 공백을 사이로 주어진다. 셋째 줄부터 K+2줄까지 건설순서 X Y가 주어진다. (이는 건물 X를 지은 다음에 건물 Y를 짓는 것이 가능하다는 의미이다)
#
# 마지막 줄에는 백준이가 승리하기 위해 건설해야 할 건물의 번호 W가 주어진다. (1 ≤ N ≤ 1000, 1 ≤ K ≤ 100000 , 1≤ X,Y,W ≤ N, 0 ≤ D ≤ 100000)
#
# ## 출력
# 건물 W를 건설완료 하는데 드는 최소 시간을 출력한다. 편의상 건물을 짓는 명령을 내리는 데는 시간이 소요되지 않는다고 가정한다.
#
# 모든 건물을 지을 수 없는 경우는 없다.
#
# ## 예제 입력 1
# 2
# 4 4
# 10 1 100 10
# 1 2
# 1 3
# 2 4
# 3 4
# 4
# 8 8
# 10 20 1 5 8 7 1 43
# 1 2
# 1 3
# 2 4
# 2 5
# 3 6
# 5 7
# 6 7
# 7 8
# 7
# ## 예제 출력 1
# 120
# 39

# %% [markdown]
# ## 문제 해결한 코드 - 일반적인 위상 정렬 알고리즘 사용
# 집입 차수가 0인 정점부터 시작으로 정점에 대한 가중치를 더 해 간다.
#
# A ->      D
# A -> C -> D 그래프의 경우 (A + D), (A + C + D) ..... 중 큰값을 정점 D에 저장
#
# BFS와 비슷해 보이지만, 그림을 그려 놓고 보면 집입 차수가 0인(리프노드) 정점을 시작으로 값이 더해 지며, 집입 차수가 0인 아닌 정점은 다른 연결된 정점중 값이 큰 것으로 저장 된다.

# %%
import sys

def topologicalSorting():
    queue = [x for x, v in enumerate(edgeCount) if v == 0 and x != 0]
    for x in queue:
        result[x] = weight[x]
    
    while(queue):
        x = queue.pop(0)
        
        for ele in adj_list[x]:
            result[ele]     = max(result[ele], result[x] + weight[ele] )
            edgeCount[ele] -= 1

            if edgeCount[ele] == 0:
                queue.append(ele)
    
data     = []

for testCase in range(int(input())):
    temp = []
    buldingCount, rules = map(lambda x:int(x), input().split())
        
    weight = list(map(lambda x:int(x), sys.stdin.readline().split()))
    weight.insert(0, 0)
    
    N         = buldingCount + 1
    adj_list  = [[] for x in range(N)]
    edgeCount = [0] * N
    
    for rule in range(1, rules + 1):
        row, col = map(lambda x:int(x),sys.stdin.readline().split())
        adj_list[row].append(col)
        edgeCount[col] += 1

    target = int(input())
    
    temp.append(buldingCount) # 0
    temp.append(rules)        # 1
    temp.append(weight)       # 2
    temp.append(adj_list)     # 3
    temp.append(target)       # 4
    temp.append(edgeCount)    # 5

    data.append(temp)

minTime = []

for testcase in data:
    buldingCount , _, weight,  adj_list, target, edgeCount = testcase
    
    visited  = [False] * (buldingCount + 1)
    result   = [0] * (buldingCount + 1)

    topologicalSorting()

    minTime.append(result[target])

    
print('\n'.join(map(str, minTime)))

# %% [markdown]
# ## 풀이
# 간단하게 위상 정렬을 통해 나온 그래프를 이용하여 각각에 정점에 대한 값만 더해 주면 된다고 생각함.

# %%
adj_list = [[], [2, 3], [3], [4], [] ]  
N        = len(adj_list) # 그래프 정점 수
visited  = [False for x in range(N+1)] # 방문되면 True로
s        = []

target = 4

def dfs(v):
    visited[v] = True  # 정점 v 방문
    
    for w in adj_list[v]: # 정점 v에 인접한 각 정점에 대해
        if not visited[w]:
            dfs(w)  # v에 인접한 방문 안된 정점 재귀호출
    
    s.append(v) # i에서 진출하는 간선이 더 이상 없으므로 i를 s에 추가 

for i in range(target):
    if not visited[i]:
        dfs(i)
s.reverse()

print('\n위상정렬:')
print(s)
# Out:
# 위상정렬:
# [1, 2, 3, 4, 0]

# %% [markdown]
# 그래프가 구해 졌지만, 1 -> 2 -> 4, 1 -> 3 -> 4 중 각각의 정점의 값을 더해 큰 값을 구해야 되는데......

# %%
adj_list = [[],
            [2, 3],
            [4, 5],
            [6],
            [],
            [7],
            [7],
            [8],
            []]

N        = len(adj_list) # 그래프 정점 수
visited  = [False for x in range(N+1)] # 방문되면 True로
s        = []

def dfs(v):
    visited[v] = True  # 정점 v 방문

    for w in adj_list[v]: # 정점 v에 인접한 각 정점에 대해
        if not visited[w]:
            dfs(w)  # v에 인접한 방문 안된 정점 재귀호출
    
    s.append(v) # i에서 진출하는 간선이 더 이상 없으므로 i를 s에 c추가 

for i in range(1, N):
    if not visited[i]:
        dfs(i)

s.reverse()

print('\n위상정렬:')
print(s)
# Out:
# 위상정렬:
# [1, 3, 6, 2, 5, 7, 8, 4]

# %% [markdown]
# 데이터가 바뀌어도 여전히 위상정려로 구해진 그래프들 중 큰 값을 구합 수 없다.

# %% [markdown]
# 아래 두 코드들은 막연하게 예제에 대한 답만 나온 경우다. 만약 특정 정정을 알고 싶다고 하면 맞는 것도 있겠지만  아닌것도 존재 한다.

# %%
adj_list = [[], [2, 3], [4], [4], [] ]  
N        = len(adj_list) # 그래프 정점 수
visited  = [False for x in range(N+1)] # 방문되면 True로
s        = []
weight   = [0, 10, 1, 100, 10]



def dfs(v, g):
    visited[v] = True  # 정점 v 방문
 
    temp = []
    temp2 = [weight[x] for x in adj_list[v]]
    gg = max( temp2 if temp2 else [0])
    print(v, g, temp, temp2)
    for w in adj_list[v]: # 정점 v에 인접한 각 정점에 대해
        value = g + gg
        if not visited[w]: 
            value = dfs(w, value)  # v에 인접한 방문 안된 정점 재귀호출
        
        temp.append(value)
        
    
    s.append(v) # i에서 진출하는 간선이 더 이상 없으므로 i를 s에 추가 
    
    return max(temp) if temp else g

for i in range(1, N):
    if not visited[i]:
        value = dfs(i, weight[i])
    
print(value)
        
s.reverse()

print('\n위상정렬:')
print(s)
# Out:
# 1 10 [] [1, 100]
# 2 110 [] [10]
# 4 120 [] []
# 3 110 [] [10]
# 120
#
# 위상정렬:
# [1, 3, 2, 4]

# %%
adj_list = [[],
            [2, 3],
            [4, 5],
            [6],
            [],
            [7],
            [7],
            [8],
            []]
N        = len(adj_list) # 그래프 정점 수
visited  = [False for x in range(N+1)] # 방문되면 True로
s        = []
weight   = [0, 10, 20, 1, 5, 8, 7, 1, 42, 0 ]

target   = 7

def dfs(v, g):
    visited[v] = True  # 정점 v 방문
 
    temp = []
    temp2 = [weight[x] for x in adj_list[v]]

    for w in adj_list[v]: # 정점 v에 인접한 각 정점에 대해
        value = g + weight[w]

        if w >= target:
            visited[v] = True
            temp.append(value)
            s.append(v)
            return max(temp) if temp else g
        

        if not visited[w] : 
            value = dfs(w, value)  # v에 인접한 방문 안된 정점 재귀호출
                    
        temp.append(value)
        
    s.append(v) # i에서 진출하는 간선이 더 이상 없으므로 i를 s에 추가 

    return max(temp) if temp else g

for i in range(1, target):
    if not visited[i]:
        value = dfs(i, weight[i])
        print(value)
        
s.reverse()

print('\n위상정렬:')
print(s)
# Out:
# 39
#
# 위상정렬:
# [1, 3, 6, 2, 5, 4]

# %% [markdown]
# '정답입니다.' 라고 나오기전까지 작성하던 코드이다.
#
# * 위상 정렬을 이용하면 시작점으로 하는 그래프를 만들수 있다. 주어진 예제에는 없지만 다른 예제들은 시작접이 여러개, 즉 그래프 자체가 트리를 구성하지 않기 않는다. 책에 있는 예제는 트리로 구성된 것이기 때문에 여기에 나온 예제와 맞지 않는다. dfs(v)메서드는 여기에 맞지 않는다.
# * 원래 위상정렬은 리프노드(즉 집입 차수가 0) 부터 탐색을 시작한다. 내가 원하는 것이 7부터 시작이니까 즉 이 정점(노드)부터 시작하면 된다고 생각 했다. 여기 까지는 좋다. 2)가 정답 처리가 안되는 이유는 한가지. 그래프에서 너비 우선 탐색이 안된다는 것이다.
#
# ~~~c
# 1) 정답 코드
# while(queue):
#     x = queue.pop(0)
#
#     for ele in adj_list[x]:
#         result[ele]     = max(result[ele], result[x] + weight[ele] )
#         edgeCount[ele] -= 1
#
#         if edgeCount[ele] == 0:
#             queue.append(ele)
#
# 2) XXXXXXX
# while(queue):
#     x = queue.pop(0)
#
#     for ele in adj_list[x]:
#         if result[ele] < result[x] + weight[ele]:
#             result[ele] = result[x] + weight[ele]
#
#         if not visited[ele]:
#             queue.append(ele)
#             visited[ele] = True
# ~~~
# * 트리는 그래프이다. 그러나 그래프는 트리가 될수도 있고 아닐 수도 있다.

# %%
import sys

def dfs(v):
    visited[v] = True  

    for w in adj_list[v]:
        if result[w] < result[v] + weight[w]:
                result[w] = result[v] + weight[w]
        if not visited[w]:
            dfs(w)
    
    top.append(v)


def bfs(v):
    queue = []
    queue.append(v)
    visited[v] = True
    
    while(queue):
        x = queue.pop(0)
        
        for ele in adj_list[x]:
            if result[ele] < result[x] + weight[ele]:
                result[ele] = result[x] + weight[ele]
                
            if not visited[ele]:
                queue.append(ele)
                visited[ele] = True
    
data     = []

testCases = int(input())
for testCase in range(testCases):
    temp = []
    buldingCount, rules = map(lambda x:int(x),input().split())
    
    weight = list(map(lambda x:int(x), sys.stdin.readline().split()))
    weight.insert(0, 0)
    
    N = buldingCount + 1

    adj_list = [[] for x in range(N)]
    
    for rule in range(1, rules + 1):
        row, col = map(lambda x:int(x),sys.stdin.readline().split())
        adj_list[col].append(row)
    
    target = int(input())
    
    temp.append(buldingCount) # 0
    temp.append(rules)        # 1
    temp.append(weight)       # 2
    temp.append(adj_list)     # 3
    temp.append(target)       # 4

    data.append(temp)

minTime = []
for testcase in data:
    buldingCount , _, weight,  adj_list, target= testcase
    
    top            = []
    visited        = [False] * (buldingCount + 1)
    result         = [0] * (buldingCount + 1)
    result[target] = weight[target]
    
    dfs(target) 
    bfs(target)

    minTime.append(max(result))

for ele in minTime:
    print(ele)
